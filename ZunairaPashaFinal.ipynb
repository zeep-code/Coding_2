# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Custom headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

main_url = 'https://katalogus.hasznaltauto.hu/'

# Implement a simple exponential backoff strategy for the main URL request
for i in range(5):
    try:
        response = requests.get(main_url, headers=headers)
        response.raise_for_status()
        break  # Success! Exit the retry loop.
    except requests.exceptions.HTTPError as e:
        if response.status_code == 429:
            wait = 2 ** i  # Exponential backoff
            print(f"Rate limited. Waiting {wait} seconds to retry...")
            time.sleep(wait)
        else:
            raise  # Re-raise the exception for other non-429 errors.

soup = BeautifulSoup(response.content, 'html.parser')

# Get brand URLs
brand_list = soup.find('ul', class_='cimkefelho')
brand_links = brand_list.find_all('a', href=True)
brands = {brand.get_text(strip=True): brand['href'] for brand in brand_links}

# Function to scrape brand pages for car links
def scrape_brand_page(brand_url, max_links_per_brand):
    car_links = []
    response = requests.get(brand_url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    listings = soup.find_all('tr', class_='paros')
    for listing in listings:
        if len(car_links) < max_links_per_brand:
            link_tag = listing.find('a', href=True)
            if link_tag:
                car_links.append(link_tag['href'])
        else:
            break
    return car_links

# Function to scrape car details
def scrape_car_details(car_detail_url):
    response = requests.get(car_detail_url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    car_details = {}

    # Extracting 'General Information'
    try:
        general_info_table = soup.find('h3', text='Általános információk').find_next('table')
        for row in general_info_table.find_all('tr'):
            cells = row.find_all('td')
            car_details[cells[0].get_text(strip=True)] = cells[1].get_text(strip=True)
    except AttributeError:
        car_details['General Information'] = 'Not available'

    # Extracting 'Equipment'
    try:
        equipment_info = soup.find('h3', text='Felszereltség').find_next('td')
        car_details['Equipment'] = equipment_info.get_text(strip=True, separator=', ')
    except AttributeError:
        car_details['Equipment'] = 'Not available'

    # Extracting 'Body Type'
    try:
        body_type_info = soup.find('h3', text='Karosszéria').find_next('table')
        for row in body_type_info.find_all('tr'):
            cells = row.find_all('td')
            car_details[cells[0].get_text(strip=True)] = cells[1].get_text(strip=True)
    except AttributeError:
        car_details['Body Type'] = 'Not available'

    # Extracting 'Dimensions and Weight'
    try:
        dimensions_table = soup.find('h3', text='Méretek és tömeg').find_next('table')
        for row in dimensions_table.find_all('tr'):
            cells = row.find_all('td')
            car_details[cells[0].get_text(strip=True)] = cells[1].get_text(strip=True)
    except AttributeError:
        car_details['Dimensions and Weight'] = 'Not available'

    # Extracting 'Engine and Transmission'
    try:
        engine_table = soup.find('h3', text='Motor és sebességváltó').find_next('table')
        for row in engine_table.find_all('tr'):
            cells = row.find_all('td')
            car_details[cells[0].get_text(strip=True)] = cells[1].get_text(strip=True)
    except AttributeError:
        car_details['Engine and Transmission'] = 'Not available'

    # Extracting 'Consumption, Acceleration, and Speed Data'
    try:
        performance_table = soup.find('h3', text='Fogyasztás, gyorsulás- és sebességadatok').find_next('table')
        for row in performance_table.find_all('tr'):
            cells = row.find_all('td')
            car_details[cells[0].get_text(strip=True)] = cells[1].get_text(strip=True)
    except AttributeError:
        car_details['Performance'] = 'Not available'

    return car_details


# Scrape links for each brand
all_car_links = []
links_per_brand = 4  # Adjust this to ensure 200 listings

for brand_name, brand_url in brands.items():
    print(f"Scraping car links from {brand_name}...")
    car_links = scrape_brand_page(brand_url, links_per_brand)
    all_car_links.extend(car_links)
    
# Place to store all car details and headers
car_details_list = []
all_headers = set()

# Scrape details for each car link (limit the number of links as needed)
for link in all_car_links[:200]:  # Adjust the slice as per your requirement
    print(f"Scraping details from {link}")
    details = scrape_car_details(link)
    car_details_list.append(details)
    all_headers.update(details.keys())

# Convert the set of headers to a list and sort it
headers = list(all_headers)
headers.sort()

# Writing to CSV
with open('car_details.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=headers)
    writer.writeheader()
    for car in car_details_list:
        # Fill missing fields with a placeholder
        row = {header: car.get(header, 'Not available') for header in headers}
        writer.writerow(row)

print("Scraping completed. Car details saved to car_details.csv.")
# Out:
# Scraping car links from ALFA ROMEO...
# Scraping car links from AUDI...
# Scraping car links from BENTLEY...
# Scraping car links from BMW...
# Scraping car links from CADILLAC...
# Scraping car links from CHEVROLET...
# Scraping car links from CHRYSLER...
# Scraping car links from CITROEN...
# Scraping car links from DACIA...
# Scraping car links from DAEWOO...
# Scraping car links from DAIHATSU...
# Scraping car links from DODGE...
# Scraping car links from FERRARI...
# Scraping car links from FIAT...
# Scraping car links from FORD...
# Scraping car links from HONDA...
# Scraping car links from HYUNDAI...
# Scraping car links from INFINITI...
# Scraping car links from JAGUAR...
# Scraping car links from JEEP...
# Scraping car links from KIA...
# Scraping car links from LADA...
# Scraping car links from LANCIA...
# Scraping car links from LAND ROVER...
# Scraping car links from LEXUS...
# Scraping car links from MASERATI...
# Scraping car links from MAZDA...
# Scraping car links from MERCEDES-AMG...
# Scraping car links from MERCEDES-BENZ...
# Scraping car links from MINI...
# Scraping car links from MITSUBISHI...
# Scraping car links from NISSAN...
# Scraping car links from OPEL...
# Scraping car links from PEUGEOT...
# Scraping car links from PORSCHE...
# Scraping car links from RENAULT...
# Scraping car links from SAAB...
# Scraping car links from SEAT...
# Scraping car links from SKODA...
# Scraping car links from SMART...
# Scraping car links from SSANGYONG...
# Scraping car links from SUBARU...
# Scraping car links from SUZUKI...
# Scraping car links from TESLA...
# Scraping car links from TOYOTA...
# Scraping car links from TRABANT...
# Scraping car links from VOLKSWAGEN...
# Scraping car links from VOLVO...
# Scraping details from https://katalogus.hasznaltauto.hu/alfa_romeo/alfa_145_1.4_l-74
# C:\Users\zunai\AppData\Local\Temp\ipykernel_3764\2235525787.py:59: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   general_info_table = soup.find('h3', text='Általános információk').find_next('table')
# C:\Users\zunai\AppData\Local\Temp\ipykernel_3764\2235525787.py:68: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   equipment_info = soup.find('h3', text='Felszereltség').find_next('td')
# C:\Users\zunai\AppData\Local\Temp\ipykernel_3764\2235525787.py:75: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   body_type_info = soup.find('h3', text='Karosszéria').find_next('table')
# C:\Users\zunai\AppData\Local\Temp\ipykernel_3764\2235525787.py:84: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   dimensions_table = soup.find('h3', text='Méretek és tömeg').find_next('table')
# C:\Users\zunai\AppData\Local\Temp\ipykernel_3764\2235525787.py:93: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   engine_table = soup.find('h3', text='Motor és sebességváltó').find_next('table')
# C:\Users\zunai\AppData\Local\Temp\ipykernel_3764\2235525787.py:102: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   performance_table = soup.find('h3', text='Fogyasztás, gyorsulás- és sebességadatok').find_next('table')
# Scraping details from https://katalogus.hasznaltauto.hu/alfa_romeo/alfa_145_1.4_ts_l-76
# Scraping details from https://katalogus.hasznaltauto.hu/alfa_romeo/alfa_145_1.6_l-78
# Scraping details from https://katalogus.hasznaltauto.hu/alfa_romeo/alfa_145_1.6_ts_l-80
# Scraping details from https://katalogus.hasznaltauto.hu/audi/100_2.2_l-2603
# Scraping details from https://katalogus.hasznaltauto.hu/audi/100_1.9_c-2605
# Scraping details from https://katalogus.hasznaltauto.hu/audi/100_2.2_gl_5_e-2607
# Scraping details from https://katalogus.hasznaltauto.hu/audi/100_2.0_d_cs_5_d-2609
# Scraping details from https://katalogus.hasznaltauto.hu/bentley/6.8_v8-67489
# Scraping details from https://katalogus.hasznaltauto.hu/bentley/6.7-67491
# Scraping details from https://katalogus.hasznaltauto.hu/bentley/6.8-67493
# Scraping details from https://katalogus.hasznaltauto.hu/bentley/4.4_32v-67495
# Scraping details from https://katalogus.hasznaltauto.hu/bmw/116i_advantage-3395
# Scraping details from https://katalogus.hasznaltauto.hu/bmw/118i_automata-3397
# Scraping details from https://katalogus.hasznaltauto.hu/bmw/120i_automata-3399
# Scraping details from https://katalogus.hasznaltauto.hu/bmw/118d-3401
# Scraping details from https://katalogus.hasznaltauto.hu/cadillac/4.6-67876
# Scraping details from https://katalogus.hasznaltauto.hu/cadillac/4.6-67878
# Scraping details from https://katalogus.hasznaltauto.hu/cadillac/4.5_16v-67880
# Scraping details from https://katalogus.hasznaltauto.hu/cadillac/bls_2.0_t_business-5063
# Scraping details from https://katalogus.hasznaltauto.hu/chevrolet/3.4_v6-68126
# Scraping details from https://katalogus.hasznaltauto.hu/chevrolet/4.3-68129
# Scraping details from https://katalogus.hasznaltauto.hu/chevrolet/4.3-68131
# Scraping details from https://katalogus.hasznaltauto.hu/chevrolet/4.3_luxury-68133
# Scraping details from https://katalogus.hasznaltauto.hu/chrysler/300_c_3.5_automata-5652
# Scraping details from https://katalogus.hasznaltauto.hu/chrysler/300_c_6.1_hemi_srt8_automata-5654
# Scraping details from https://katalogus.hasznaltauto.hu/chrysler/300_c_touring_3.5_automata-5656
# Scraping details from https://katalogus.hasznaltauto.hu/chrysler/300_c_touring_5.7_hemi_automata-5658
# Scraping details from https://katalogus.hasznaltauto.hu/citroen/2_cv_club-5917
# Scraping details from https://katalogus.hasznaltauto.hu/citroen/8-76923
# Scraping details from https://katalogus.hasznaltauto.hu/citroen/10_super-76925
# Scraping details from https://katalogus.hasznaltauto.hu/citroen/10_super-76927
# Scraping details from https://katalogus.hasznaltauto.hu/dacia/1.3-69207
# Scraping details from https://katalogus.hasznaltauto.hu/dacia/1.3-69209
# Scraping details from https://katalogus.hasznaltauto.hu/dacia/1304_1.4_drop-side-105314
# Scraping details from https://katalogus.hasznaltauto.hu/dacia/1307_1.4_dubla_cabina-105315
# Scraping details from https://katalogus.hasznaltauto.hu/daewoo/espero_1.5i_16v_glx-7707
# Scraping details from https://katalogus.hasznaltauto.hu/daewoo/espero_1.8i_cd-7709
# Scraping details from https://katalogus.hasznaltauto.hu/daewoo/espero_1.8i_cd-7711
# Scraping details from https://katalogus.hasznaltauto.hu/daewoo/espero_2.0i_cd-7713
# Scraping details from https://katalogus.hasznaltauto.hu/daihatsu/applause_1.6_li-7820
# Scraping details from https://katalogus.hasznaltauto.hu/daihatsu/applause_1.6_xi-7822
# Scraping details from https://katalogus.hasznaltauto.hu/daihatsu/applause_1.6_li-7824
# Scraping details from https://katalogus.hasznaltauto.hu/daihatsu/applause_1.6_xi_klima-7826
# Scraping details from https://katalogus.hasznaltauto.hu/dodge/2.6_8v-83676
# Scraping details from https://katalogus.hasznaltauto.hu/dodge/2.5_8v-83678
# Scraping details from https://katalogus.hasznaltauto.hu/dodge/2.6_8v-83680
# Scraping details from https://katalogus.hasznaltauto.hu/dodge/2.5_8v-83682
# Scraping details from https://katalogus.hasznaltauto.hu/ferrari/308_gts-70041
# Scraping details from https://katalogus.hasznaltauto.hu/ferrari/308_gtb_qv-70043
# Scraping details from https://katalogus.hasznaltauto.hu/ferrari/3.3-70046
# Scraping details from https://katalogus.hasznaltauto.hu/ferrari/3.0_32v-70048
# Scraping details from https://katalogus.hasznaltauto.hu/fiat/1.2-70195
# Scraping details from https://katalogus.hasznaltauto.hu/fiat/1600_sport-78089
# Scraping details from https://katalogus.hasznaltauto.hu/fiat/1800_sport-78091
# Scraping details from https://katalogus.hasznaltauto.hu/fiat/1800_sport-78093
# Scraping details from https://katalogus.hasznaltauto.hu/ford/4.0_12v-70210
# Scraping details from https://katalogus.hasznaltauto.hu/ford/2.3_8v-70212
# Scraping details from https://katalogus.hasznaltauto.hu/ford/4.0_12v_awd-70214
# Scraping details from https://katalogus.hasznaltauto.hu/ford/2.8_12v-70216
# Scraping details from https://katalogus.hasznaltauto.hu/honda/accord_1.6_l-12813
# Scraping details from https://katalogus.hasznaltauto.hu/honda/accord_1.6_hatchback-12815
# Scraping details from https://katalogus.hasznaltauto.hu/honda/accord_1.6-12817
# Scraping details from https://katalogus.hasznaltauto.hu/honda/accord_1.6_ex-12819
# Scraping details from https://katalogus.hasznaltauto.hu/hyundai/accent_1.3_ls-13237
# Scraping details from https://katalogus.hasznaltauto.hu/hyundai/accent_1.3_ls-13239
# Scraping details from https://katalogus.hasznaltauto.hu/hyundai/accent_1.5_pro_ls-13241
# Scraping details from https://katalogus.hasznaltauto.hu/hyundai/accent_1.5_gt-13243
# Scraping details from https://katalogus.hasznaltauto.hu/infiniti/30d-77862
# Scraping details from https://katalogus.hasznaltauto.hu/infiniti/3.5_4wd-88602
# Scraping details from https://katalogus.hasznaltauto.hu/infiniti/ex37_3.7_v6_automata-59687
# Scraping details from https://katalogus.hasznaltauto.hu/infiniti/ex37_3.7_v6_gt_automata-59689
# Scraping details from https://katalogus.hasznaltauto.hu/jaguar/e-pace_p250_s_automata-111280
# Scraping details from https://katalogus.hasznaltauto.hu/jaguar/e-pace_p250_hse_automata-111282
# Scraping details from https://katalogus.hasznaltauto.hu/jaguar/e-pace_p250_r-dynamic_s_automata-111284
# Scraping details from https://katalogus.hasznaltauto.hu/jaguar/e-pace_p250_r-dynamic_hse_automata-111286
# Scraping details from https://katalogus.hasznaltauto.hu/jeep/avenger_54_kwh_bev_altitude-144144
# Scraping details from https://katalogus.hasznaltauto.hu/jeep/cherokee_2.5-59823
# Scraping details from https://katalogus.hasznaltauto.hu/jeep/cherokee_4.0_euro-59825
# Scraping details from https://katalogus.hasznaltauto.hu/jeep/cherokee_4.0_automata-59827
# Scraping details from https://katalogus.hasznaltauto.hu/kia/1.5-71525
# Scraping details from https://katalogus.hasznaltauto.hu/kia/1.5-71527
# Scraping details from https://katalogus.hasznaltauto.hu/kia/besta_2.2_d-51047
# Scraping details from https://katalogus.hasznaltauto.hu/kia/2.7_d-85952
# Scraping details from https://katalogus.hasznaltauto.hu/lada/1.5-71546
# Scraping details from https://katalogus.hasznaltauto.hu/lada/2.0_i-71548
# Scraping details from https://katalogus.hasznaltauto.hu/lada/1.5-71550
# Scraping details from https://katalogus.hasznaltauto.hu/lada/1.6-71552
# Scraping details from https://katalogus.hasznaltauto.hu/lancia/a_112_1.0_elite-14975
# Scraping details from https://katalogus.hasznaltauto.hu/lancia/a_112_1.0_abarth-14977
# Scraping details from https://katalogus.hasznaltauto.hu/lancia/beta_berlina-15106
# Scraping details from https://katalogus.hasznaltauto.hu/lancia/beta_1600_coupe-15108
# Scraping details from https://katalogus.hasznaltauto.hu/land_rover/2.5-71671
# Scraping details from https://katalogus.hasznaltauto.hu/land_rover/2.5_d_4x4-71673
# Scraping details from https://katalogus.hasznaltauto.hu/land_rover/2.3_4x4-71675
# Scraping details from https://katalogus.hasznaltauto.hu/land_rover/defender_90_hard_top_3.5-60696
# Scraping details from https://katalogus.hasznaltauto.hu/lexus/ct_200h_comfort_automata-15280
# Scraping details from https://katalogus.hasznaltauto.hu/lexus/ct_200h_executivenavigation_automata-15282
# Scraping details from https://katalogus.hasznaltauto.hu/lexus/ct_200h_f-sport_automata-15284
# Scraping details from https://katalogus.hasznaltauto.hu/lexus/ct_200h_mark_levinson_top_automata-15286
# Scraping details from https://katalogus.hasznaltauto.hu/maserati/420_i-76976
# Scraping details from https://katalogus.hasznaltauto.hu/maserati/2.8_bi_turbo-76978
# Scraping details from https://katalogus.hasznaltauto.hu/maserati/2.0-76980
# Scraping details from https://katalogus.hasznaltauto.hu/maserati/a6gcm-71881
# Scraping details from https://katalogus.hasznaltauto.hu/mazda/121_1.3_lx-15540
# Scraping details from https://katalogus.hasznaltauto.hu/mazda/121_1.3_baby_s-15542
# Scraping details from https://katalogus.hasznaltauto.hu/mazda/121_1.3_lx_canvas_top-15544
# Scraping details from https://katalogus.hasznaltauto.hu/mazda/121_1.3_lx-15546
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-amg/amg_gt_roadster_4.0_automata-103880
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-amg/amg_gt_coupe_4.0_c_automata-112475
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-amg/amg_gt_coupe_63_4matic_plusz_9g-tronic-115694
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-amg/amg_gt_coupe_43_9g-t_eq_boost-117578
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-benz/190-17226
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-benz/190_e-17228
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-benz/190-17230
# Scraping details from https://katalogus.hasznaltauto.hu/mercedes-benz/190-17232
# Scraping details from https://katalogus.hasznaltauto.hu/mini/mini_cooper_1.6_cabrio-19821
# Scraping details from https://katalogus.hasznaltauto.hu/mini/mini_cooper_1.6_s_cabrio-19823
# Scraping details from https://katalogus.hasznaltauto.hu/mini/mini_one_cabrio_1.6-19843
# Scraping details from https://katalogus.hasznaltauto.hu/mini/mini_cooper_cabrio_1.6-19845
# Scraping details from https://katalogus.hasznaltauto.hu/mitsubishi/asx_1.6_mivec_invite-20609
# Scraping details from https://katalogus.hasznaltauto.hu/mitsubishi/asx_1.6_mivec_instyle_navi-20611
# Scraping details from https://katalogus.hasznaltauto.hu/mitsubishi/asx_1.8_di-d_invite-20613
# Scraping details from https://katalogus.hasznaltauto.hu/mitsubishi/asx_1.8_di-d_intense-20615
# Scraping details from https://katalogus.hasznaltauto.hu/nissan/100_nx_slx_styling_kit-22129
# Scraping details from https://katalogus.hasznaltauto.hu/nissan/100_nx_t-roof-22131
# Scraping details from https://katalogus.hasznaltauto.hu/nissan/100_nx_gti-22133
# Scraping details from https://katalogus.hasznaltauto.hu/nissan/100_nx_gti_t-roof_t-bar-22135
# Scraping details from https://katalogus.hasznaltauto.hu/opel/adam_1.2_start-stop_selection-22255
# Scraping details from https://katalogus.hasznaltauto.hu/opel/adam_1.2_start-stop_jam-22257
# Scraping details from https://katalogus.hasznaltauto.hu/opel/adam_1.2_start-stop_glam-22259
# Scraping details from https://katalogus.hasznaltauto.hu/opel/adam_1.2_start-stop_slam-22261
# Scraping details from https://katalogus.hasznaltauto.hu/peugeot/1007_1.4_trendy-27432
# Scraping details from https://katalogus.hasznaltauto.hu/peugeot/1007_1.4_16v_trendy-27434
# Scraping details from https://katalogus.hasznaltauto.hu/peugeot/1007_1.6_trendy_automata-27436
# Scraping details from https://katalogus.hasznaltauto.hu/peugeot/1007_1.6_sporty_automata-27438
# Scraping details from https://katalogus.hasznaltauto.hu/porsche/a_1600_super-74096
# Scraping details from https://katalogus.hasznaltauto.hu/porsche/b_1600_super_75-74098
# Scraping details from https://katalogus.hasznaltauto.hu/porsche/c_1600-74100
# Scraping details from https://katalogus.hasznaltauto.hu/porsche/b_2000_gs_carrera_2-74102
# Scraping details from https://katalogus.hasznaltauto.hu/renault/agora-84626
# Scraping details from https://katalogus.hasznaltauto.hu/renault/1.4_8v-85994
# Scraping details from https://katalogus.hasznaltauto.hu/renault/1.7_8v-85996
# Scraping details from https://katalogus.hasznaltauto.hu/renault/1.4_8v-85998
# Scraping details from https://katalogus.hasznaltauto.hu/saab/9-3_2.0_base-33278
# Scraping details from https://katalogus.hasznaltauto.hu/saab/9-3_2.0_s-33280
# Scraping details from https://katalogus.hasznaltauto.hu/saab/9-3_2.0_se-33282
# Scraping details from https://katalogus.hasznaltauto.hu/saab/9-3_2.0_eco_turbo_base_automata-33284
# Scraping details from https://katalogus.hasznaltauto.hu/seat/2.0-74444
# Scraping details from https://katalogus.hasznaltauto.hu/seat/1.5-74446
# Scraping details from https://katalogus.hasznaltauto.hu/seat/0.9-74448
# Scraping details from https://katalogus.hasznaltauto.hu/seat/0.9-74450
# Scraping details from https://katalogus.hasznaltauto.hu/skoda/100-35503
# Scraping details from https://katalogus.hasznaltauto.hu/skoda/s_105_l-35505
# Scraping details from https://katalogus.hasznaltauto.hu/skoda/105_l-35507
# Scraping details from https://katalogus.hasznaltauto.hu/skoda/1.1_l-74647
# Scraping details from https://katalogus.hasznaltauto.hu/smart/forfour_1.0_pure_softouch-37530
# Scraping details from https://katalogus.hasznaltauto.hu/smart/forfour_1.1_pure_softouch-37532
# Scraping details from https://katalogus.hasznaltauto.hu/smart/forfour_1.1_pulse_softouch-37534
# Scraping details from https://katalogus.hasznaltauto.hu/smart/forfour_1.1_passion_softouch-37536
# Scraping details from https://katalogus.hasznaltauto.hu/ssangyong/actyon_2.0_xdi_plus-61747
# Scraping details from https://katalogus.hasznaltauto.hu/ssangyong/actyon_2.0_xdi_premium-61749
# Scraping details from https://katalogus.hasznaltauto.hu/ssangyong/actyon_sports_2.0_xdi_plus_i._automata-56729
# Scraping details from https://katalogus.hasznaltauto.hu/ssangyong/actyon_sports_2.0_xdi_premium_i.-56731
# Scraping details from https://katalogus.hasznaltauto.hu/subaru/b9_tribeca_3.0_comfort_automata-61792
# Scraping details from https://katalogus.hasznaltauto.hu/subaru/b9_tribeca_3.6_active_automata-61794
# Scraping details from https://katalogus.hasznaltauto.hu/subaru/b9_tribeca_3.6_exclusive_automata-61796
# Scraping details from https://katalogus.hasznaltauto.hu/subaru/2.5_16v_turbo_awd-74685
# Scraping details from https://katalogus.hasznaltauto.hu/suzuki/address_110-102787
# Scraping details from https://katalogus.hasznaltauto.hu/suzuki/alto_0.8_ge-38235
# Scraping details from https://katalogus.hasznaltauto.hu/suzuki/alto_0.8_gl-38237
# Scraping details from https://katalogus.hasznaltauto.hu/suzuki/alto_0.8_gl-38239
# Scraping details from https://katalogus.hasznaltauto.hu/tesla/model_3_long_range_awd_automata-121796
# Scraping details from https://katalogus.hasznaltauto.hu/tesla/model_3_rwd_automata-138920
# Scraping details from https://katalogus.hasznaltauto.hu/tesla/model_3_performance_awd_automata-138922
# Scraping details from https://katalogus.hasznaltauto.hu/tesla/model_3_rwd_premium_automata-145362
# Scraping details from https://katalogus.hasznaltauto.hu/toyota/4-runner_3.0_v6-62161
# Scraping details from https://katalogus.hasznaltauto.hu/toyota/4runner_3.0_v6-62163
# Scraping details from https://katalogus.hasznaltauto.hu/toyota/4runner_3.0_td-62165
# Scraping details from https://katalogus.hasznaltauto.hu/toyota/auris_1.33-39644
# Scraping details from https://katalogus.hasznaltauto.hu/trabant/1.1-40312
# Scraping details from https://katalogus.hasznaltauto.hu/trabant/601_s-40310
# Scraping details from https://katalogus.hasznaltauto.hu/trabant/0.6-76644
# Scraping details from https://katalogus.hasznaltauto.hu/trabant/0.6-76647
# Scraping details from https://katalogus.hasznaltauto.hu/volkswagen/1.5_s-89622
# Scraping details from https://katalogus.hasznaltauto.hu/volkswagen/1.6-89626
# Scraping details from https://katalogus.hasznaltauto.hu/volkswagen/1.6_tl-89629
# Scraping details from https://katalogus.hasznaltauto.hu/volkswagen/1.5-89631
# Scraping details from https://katalogus.hasznaltauto.hu/volvo/1.8_s-89071
# Scraping details from https://katalogus.hasznaltauto.hu/volvo/2.0_s-89073
# Scraping details from https://katalogus.hasznaltauto.hu/volvo/2.0-89075
# Scraping details from https://katalogus.hasznaltauto.hu/volvo/2.0_s-89077
# Scraping completed. Car details saved to car_details.csv.
